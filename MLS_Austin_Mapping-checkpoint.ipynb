# %%
#import dependencies.
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder, LabelEncoder , StandardScaler, imputation
from sklearn.cluster import DBSCAN
from sklearn.cross_validation import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Pulling data in from Gmaps
# Was working on a clustering timeseries. Could possilby give the desired results with areas and timeframe

# %%
#pulling in data
mls = pd.read_csv('./computed_data/2018-09-27_MLS_Austin_gmaps.csv')

# %%
#dropping index info
mls.drop(columns='key_0',inplace=True)

# %%
mls['date'].fillna(0,inplace=True)

# %%
mls['status']= mls['status'].map({'Active':1,'Not_Active':0})

# %%
#mapping the data that was on MLS(1 - pos) vs not (0 - neg)
pos = mls[mls['status'] == 1][['geometry.location.lat','geometry.location.lng']]
neg = mls[mls['status'] == 0][['geometry.location.lat','geometry.location.lng']]

# %%
X = mls['geometry.location.lat']
y = mls['geometry.location.lng']

# %% [markdown]
# ## Returning a scatter plot of data and hot spots.

# %%
plt.scatter(neg['geometry.location.lat'],neg['geometry.location.lng'],c='blue',marker='+',alpha=.1)
plt.scatter(pos['geometry.location.lat'],pos['geometry.location.lng'],c='red',marker='o',alpha=.7)
